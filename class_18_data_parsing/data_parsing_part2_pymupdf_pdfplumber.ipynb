# %%
print("all ok")
# Out:
# all ok

# %% [markdown]
# <!-- Students, a complex PDF may contain normal text, scanned pages, tables and images. One parser may not extract everything correctly. Therefore, we use PyMuPDF for text and images, Tesseract for OCR, pdfplumber for tables, and finally convert the extracted content into LangChain Documents so it can be used in a RAG pipeline. -->

# %% [markdown]
# Students, a complex PDF may contain normal text, scanned pages, tables and images. One parser may not extract everything correctly. Therefore, we use PyMuPDF for text and images, Tesseract for OCR, pdfplumber for tables, and finally convert the extracted content into LangChain Documents so it can be used in a RAG pipeline.

# %%
# ============================================================
# Complex PDF Parser for RAG
# Text + Tables + Images + OCR + LangChain Documents
# ============================================================

# Install dependencies

import os
import json
import fitz  # PyMuPDF
import pdfplumber
import pandas as pd
from PIL import Image
from pathlib import Path
from langchain_core.documents import Document

# %%
import os
import pytesseract
from PIL import Image

TESSERACT_PATH = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

if not os.path.exists(TESSERACT_PATH):
    raise FileNotFoundError(
        f"Tesseract executable not found at: {TESSERACT_PATH}"
    )

pytesseract.pytesseract.tesseract_cmd = TESSERACT_PATH

print("Tesseract version:", pytesseract.get_tesseract_version())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 import pytesseract
#       3 from PIL import Image
#       4
#       5 TESSERACT_PATH = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
#
# ModuleNotFoundError: No module named 'pytesseract'

# %%
# ============================================================
# 1. File Path
# ============================================================

PDF_PATH = r"C:\Users\ASUS\Desktop\Gen AI Full stak\class_18_data_parsing\data\complex_rag_parsing_sample_with_sunny_image.pdf"

OUTPUT_DIR = Path(r"C:\Users\ASUS\Desktop\Gen AI Full stak\class_18_data_parsing\data\parsed_complex_pdf_output")

IMAGE_DIR = OUTPUT_DIR / "extracted_images"
PAGE_IMAGE_DIR = OUTPUT_DIR / "page_images"

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
IMAGE_DIR.mkdir(parents=True, exist_ok=True)
PAGE_IMAGE_DIR.mkdir(parents=True, exist_ok=True)

print("PDF exists:", os.path.exists(PDF_PATH))
# Out:
# PDF exists: True

# %%
# ============================================================
# 2. Helper: Safe OCR
# ============================================================

def run_ocr_on_image(image_path):
    """
    Runs OCR on image using pytesseract.
    If tesseract is not installed in system, it will return empty text.
    """
    try:
        import pytesseract
        img = Image.open(image_path)
        text = pytesseract.image_to_string(img)
        return text.strip()
    except Exception as e:
        return f"[OCR_SKIPPED_OR_FAILED: {str(e)}]"

# %%
run_ocr_on_image(r"C:\Users\ASUS\Desktop\Gen AI Full stak\class_18_data_parsing\data\parsed_complex_pdf_output\extracted_images\page_002_image_1.png")
# Out:
# "[OCR_SKIPPED_OR_FAILED: No module named 'pytesseract']"

# %%
# ============================================================
# 3. Extract Text + Images using PyMuPDF
# ============================================================

def extract_text_and_images(pdf_path):
    doc = fitz.open(pdf_path)

    page_records = []
    image_records = []

    for page_index in range(len(doc)):
        page = doc[page_index]
        page_number = page_index + 1

        # Extract normal selectable text
        text = page.get_text("text")

        # Extract page metadata-like info
        page_info = {
            "page_number": page_number,
            "text": text.strip(),
            "image_count": len(page.get_images(full=True)),
            "width": page.rect.width,
            "height": page.rect.height,
        }

        page_records.append(page_info)

        # Render full page as image for OCR
        pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))
        page_image_path = PAGE_IMAGE_DIR / f"page_{page_number:03d}.png"
        pix.save(str(page_image_path))

        # OCR full page image
        ocr_text = run_ocr_on_image(page_image_path)
        page_info["ocr_text"] = ocr_text
        page_info["page_image_path"] = str(page_image_path)

        # Extract embedded images
        images = page.get_images(full=True)

        for img_index, img in enumerate(images):
            xref = img[0]
            base_image = doc.extract_image(xref)

            image_bytes = base_image["image"]
            image_ext = base_image["ext"]

            image_path = IMAGE_DIR / f"page_{page_number:03d}_image_{img_index + 1}.{image_ext}"

            with open(image_path, "wb") as f:
                f.write(image_bytes)

            image_ocr_text = run_ocr_on_image(image_path)

            image_records.append({
                "page_number": page_number,
                "image_index": img_index + 1,
                "image_path": str(image_path),
                "image_ext": image_ext,
                "image_ocr_text": image_ocr_text
            })

    doc.close()

    return page_records, image_records

# %%
page_records, image_records = extract_text_and_images(PDF_PATH)

print("Total pages parsed:", len(page_records))
print("Total images extracted:", len(image_records))
# Out:
# Total pages parsed: 24
# Total images extracted: 13

# %%
# ============================================================
# 4. Extract Tables using pdfplumber
# ============================================================

def extract_tables(pdf_path):
    table_records = []

    with pdfplumber.open(pdf_path) as pdf:
        for page_index, page in enumerate(pdf.pages):
            page_number = page_index + 1

            try:
                tables = page.extract_tables()
            except Exception as e:
                tables = []
                print(f"Table extraction failed on page {page_number}: {e}")

            for table_index, table in enumerate(tables):
                if not table:
                    continue

                # Clean table rows
                cleaned_table = []
                for row in table:
                    cleaned_row = [
                        cell.strip() if isinstance(cell, str) else cell
                        for cell in row
                    ]
                    cleaned_table.append(cleaned_row)

                # Convert to DataFrame safely
                try:
                    df = pd.DataFrame(cleaned_table[1:], columns=cleaned_table[0])
                except Exception:
                    df = pd.DataFrame(cleaned_table)

                table_records.append({
                    "page_number": page_number,
                    "table_index": table_index + 1,
                    "raw_table": cleaned_table,
                    "markdown": df.to_markdown(index=False),
                    "csv": df.to_csv(index=False)
                })

    return table_records


table_records = extract_tables(PDF_PATH)

print("Total tables extracted:", len(table_records))

for table in table_records[:3]:
    print("\nPage:", table["page_number"], "Table:", table["table_index"])
    print(table["markdown"][:1000])
# Out:
# Total tables extracted: 16
#
# Page: 1 Table: 1
# | Section               | Parsing challenge                       | Why it matters for RAG                  |
# |:----------------------|:----------------------------------------|:----------------------------------------|
# | Contracts             | Dense legal text, clause numbers, cross | Need section-aware chunks and citations |
# |                       | references                              |                                         |
# | Tables                | Merged headers, numeric columns,        | Need row/column preservation            |
# |                       | footnotes                               |                                         |
# | Images                | Architecture diagram, heatmap, scanned  | Need OCR or multimodal extraction       |
# |                       | form                                    |                                         |
# | Multi-tenant metadata | client_id, document_id,                 | Need access-safe retrieval              |
# |
#
# Page: 2 Table: 1
# | Client            | Main document family        | Risk   | Primary users        | Typical question                    |
# |:------------------|:----------------------------|:-------|:---------------------|:------------------------------------|
# | Arka Finance      | MSA, audit addendum, DPA    | High   | Legal and compliance | What audit rights exist in the DPA? |
# | BlueLeaf Retail   | MSA, pricing, support SLA   | Medium | Procurement          | Which clause controls renewal       |
# |                   |                             |        |                      | pricing?                            |
# | CityRide Mobility | Ops reports, incident logs, | Medium | Operations           | Which depot had repeated battery    |
# |                   | SOPs                        |        |                      | incidents?                          |
#
# Page: 3 Table: 1
# | Asset ID     | Client            | Format      | Pages/Rows   | Expected extraction          | Notes                         |
# |:-------------|:------------------|:------------|:-------------|:-----------------------------|:------------------------------|
# | ARK-MSA-001  | Arka Finance      | PDF         | 32 pages     | Clauses, tables, signatures  | Born-digital text with footer |
# |              |                   |             |              |                              | references                    |
# | ARK-DPA-002  | Arka Finance      | DOCX        | 18 pages     | Headings, lists, tables      | Track changes removed         |
# |              |                   |             |              |                              | before ingestion              |
# | BLR-PRICE-00 | BlueLeaf Retail   | XLSX        | 12 sheets    | Rate cards, discounts        | Merged cells and formulas     |
# | 3            |                   |             |              |                              |

# %%
# ============================================================
# 5. Create LangChain Documents
# ============================================================

langchain_docs = []

# 5.1 Page text documents
for page in page_records:
    page_number = page["page_number"]

    combined_text = f"""
PAGE {page_number}

SELECTABLE TEXT:
{page["text"]}

OCR TEXT:
{page["ocr_text"]}
""".strip()

    doc = Document(
        page_content=combined_text,
        metadata={
            "source": PDF_PATH,
            "page_number": page_number,
            "content_type": "page_text_plus_ocr",
            "image_count": page["image_count"],
            "page_image_path": page["page_image_path"],
        }
    )

    langchain_docs.append(doc)


# 5.2 Table documents
for table in table_records:
    page_number = table["page_number"]

    table_text = f"""
TABLE FOUND ON PAGE {page_number}
TABLE INDEX: {table["table_index"]}

TABLE MARKDOWN:
{table["markdown"]}
""".strip()

    doc = Document(
        page_content=table_text,
        metadata={
            "source": PDF_PATH,
            "page_number": page_number,
            "content_type": "table",
            "table_index": table["table_index"],
        }
    )

    langchain_docs.append(doc)

# %%
# 5.3 Image OCR documents
for image in image_records:
    page_number = image["page_number"]

    image_text = f"""
IMAGE FOUND ON PAGE {page_number}
IMAGE INDEX: {image["image_index"]}
IMAGE PATH: {image["image_path"]}

IMAGE OCR TEXT:
{image["image_ocr_text"]}
""".strip()

    doc = Document(
        page_content=image_text,
        metadata={
            "source": PDF_PATH,
            "page_number": page_number,
            "content_type": "image",
            "image_index": image["image_index"],
            "image_path": image["image_path"],
            "image_ext": image["image_ext"],
        }
    )

    langchain_docs.append(doc)


print("Total LangChain Documents created:", len(langchain_docs))
# Out:
# Total LangChain Documents created: 53

# %%
# ============================================================
# 6. Save Parsed Output
# ============================================================

# Save page records
with open(OUTPUT_DIR / "page_records.json", "w", encoding="utf-8") as f:
    json.dump(page_records, f, indent=2, ensure_ascii=False)

# Save image records
with open(OUTPUT_DIR / "image_records.json", "w", encoding="utf-8") as f:
    json.dump(image_records, f, indent=2, ensure_ascii=False)

# Save table records
with open(OUTPUT_DIR / "table_records.json", "w", encoding="utf-8") as f:
    json.dump(table_records, f, indent=2, ensure_ascii=False)

# Save all LangChain document content as markdown
with open(OUTPUT_DIR / "rag_ready_documents.md", "w", encoding="utf-8") as f:
    for i, doc in enumerate(langchain_docs):
        f.write(f"\n\n# Document {i + 1}\n")
        f.write(f"\nMetadata:\n```json\n{json.dumps(doc.metadata, indent=2)}\n```\n")
        f.write("\nContent:\n")
        f.write(doc.page_content)
        f.write("\n\n---\n")

# Save table markdown separately
with open(OUTPUT_DIR / "extracted_tables.md", "w", encoding="utf-8") as f:
    for table in table_records:
        f.write(f"\n\n## Page {table['page_number']} - Table {table['table_index']}\n\n")
        f.write(table["markdown"])
        f.write("\n\n---\n")

print("\nSaved outputs in:", OUTPUT_DIR)
# Out:
# Saved outputs in: C:\Users\ASUS\Desktop\Gen AI Full stak\class_18_data_parsing\data\parsed_complex_pdf_output

# %%
# ============================================================
# 7. Preview Parsed Output
# ============================================================

print("\n================ PAGE TEXT PREVIEW ================\n")
print(langchain_docs[0].page_content[:1500])

print("\n================ TABLE PREVIEW ================\n")
table_docs = [doc for doc in langchain_docs if doc.metadata["content_type"] == "table"]

if table_docs:
    print(table_docs[0].page_content[:1500])
else:
    print("No table docs found.")

print("\n================ IMAGE OCR PREVIEW ================\n")
image_docs = [doc for doc in langchain_docs if doc.metadata["content_type"] == "image"]

if image_docs:
    print(image_docs[0].page_content[:1500])
else:
    print("No image docs found.")
# Out:
# ================ PAGE TEXT PREVIEW ================
#
# PAGE 1
#
# SELECTABLE TEXT:
# Complex RAG Parsing Sample - synthetic document
# Page 1
# Complex Document for RAG Parsing Tests
# Synthetic 15-page PDF with paragraphs, simple and complex tables, diagrams, scanned-form style image, metadata
# examples, and production RAG edge cases.
# Story Line
# Three client teams - Arka Finance, BlueLeaf Retail, and CityRide Mobility - are migrating contracts, policies, support records,
# and operational reports into a single RAG platform. Each team has different document types, access rules, and parsing
# challenges. The RAG system must answer questions with citations while ensuring that one client never sees another clients
# data.
# This PDF is intentionally designed to test document loaders, PDF parsers, OCR workflows, table extraction, chunking
# strategies, metadata preservation, and source citation quality.
# Key statement: RAG does not train the model. RAG gives the model the right context before answering.
# Section
# Parsing challenge
# Why it matters for RAG
# Contracts
# Dense legal text, clause numbers, cross
# references
# Need section-aware chunks and citations
# Tables
# Merged headers, numeric columns,
# footnotes
# Need row/column preservation
# Images
# Architecture diagram, heatmap, scanned
# form
# Need OCR or multimodal extraction
# Multi-tenant metadata
# client_id, document_id,
# contract_group_id
# Need access-safe retrieval
#
# OCR TEXT:
# Complex Document for RAG Parsing Tests
#
# Synthetic 15-page PDF with paragraphs, simple and complex tables, diagrams, scanned-form style image, metad
#
# ================ TABLE PREVIEW ================
#
# TABLE FOUND ON PAGE 1
# TABLE INDEX: 1
#
# TABLE MARKDOWN:
# | Section               | Parsing challenge                       | Why it matters for RAG                  |
# |:----------------------|:----------------------------------------|:----------------------------------------|
# | Contracts             | Dense legal text, clause numbers, cross | Need section-aware chunks and citations |
# |                       | references                              |                                         |
# | Tables                | Merged headers, numeric columns,        | Need row/column preservation            |
# |                       | footnotes                               |                                         |
# | Images                | Architecture diagram, heatmap, scanned  | Need OCR or multimodal extraction       |
# |                       | form                                    |                                         |
# | Multi-tenant metadata | client_id, document_id,                 | Need access-safe retrieval              |
# |                       | contract_group_id                       |                                         |
#
# ================ IMAGE OCR PREVIEW ================
#
# IMAGE FOUND ON PAGE 2
# IMAGE INDEX: 1
# IMAGE PATH: D:\complete_content_new\Full-Stack-GenAI-Bootcamp-1.0\Class-30-Data-Parsing-for-RAG\data\parsed_complex_pdf_output\extracted_images\page_002_image_1.png
#
# IMAGE OCR TEXT:
# Contract Processing Ownership Map
#
# Client Admin Audit Team
#
# Vector DB Document Store

# %%
# # ============================================================
# # Complex PDF Parsing using Docling
# # PDF -> DoclingDocument -> Markdown / JSON / LangChain Documents
# # ============================================================

# # Install dependencies
# !pip install -q docling langchain-core langchain-text-splitters pandas

import json
from pathlib import Path
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# ============================================================
# 1. Input PDF Path
# ============================================================

PDF_PATH = r"C:\Users\ASUS\Desktop\Gen AI Full stak\class_18_data_parsing\data\complex_rag_parsing_sample_with_sunny_image.pdf"

OUTPUT_DIR = Path(r"C:\Users\ASUS\Desktop\Gen AI Full stak\class_18_data_parsing\output\docling_parsed_output")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("PDF path:", PDF_PATH)
# Out:
# PDF path: C:\Users\ASUS\Desktop\Gen AI Full stak\class_18_data_parsing\data\complex_rag_parsing_sample_with_sunny_image.pdf

# %%
import torch

# Disable torch compile / dynamo compilation
torch._dynamo.config.suppress_errors = True

from docling.document_converter import DocumentConverter

converter = DocumentConverter()

conversion_result = converter.convert(PDF_PATH)

docling_doc = conversion_result.document

print("Docling conversion completed.")
# Out:
# [INFO] 2026-09-13 22:59:45,880 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-13 22:59:45,906 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.onnx
# [INFO] 2026-09-13 22:59:45,908 [RapidOCR] main.py:63: Using C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.onnx
# [INFO] 2026-09-13 22:59:45,997 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-13 22:59:46,005 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-09-13 22:59:46,006 [RapidOCR] main.py:63: Using C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-09-13 22:59:46,063 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-13 22:59:46,148 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\PP-OCRv6_rec_small.onnx
# [INFO] 2026-09-13 22:59:46,149 [RapidOCR] main.py:63: Using C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\PP-OCRv6_rec_small.onnx
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] WON'T CONVERT forward c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\transformers\models\rt_detr_v2\modeling_rt_detr_v2.py line 1841
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] due to:
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Traceback (most recent call last):
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 2052, in __call__
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = self._inner_convert(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 729, in __call__
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = _compile(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1827, in _compile
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     guarded_code, tracer_output = compile_inner(code, one_graph, hooks)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_utils_internal.py", line 96, in wrapper_function
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return function(*args, **kwargs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1500, in compile_inner
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_inner(code, one_graph, hooks)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1534, in _compile_inner
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     dynamo_output = compile_frame(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1408, in compile_frame
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     bytecode, tracer_output = transform_code_object(code, transform)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1608, in transform_code_object
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = transformations(instructions, code_options)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1380, in transform
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = trace_frame(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 341, in _fn
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return fn(*args, **kwargs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 863, in trace_frame
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     run_tracer()
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 844, in run_tracer
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer.run()
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1794, in run
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     while self.step():
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]           ^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1459, in step
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.dispatch_table[inst.opcode](self, inst)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5570, in RETURN_VALUE
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self._return(inst)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5552, in _return
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     all_stack_locals_metadata = self.output.compile_subgraph(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 1889, in compile_subgraph
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2460, in compile_and_call_fx_graph
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = self.call_user_compiler(gm, self.example_inputs())
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2613, in call_user_compiler
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return self._call_user_compiler(gm, example_inputs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2664, in _call_user_compiler
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = compiler_fn(gm, example_inputs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 156, in __call__
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_gm = compiler_fn(gm, example_inputs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\__init__.py", line 2461, in __call__
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2578, in compile_fx
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _maybe_wrap_and_compile_fx_main(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2655, in _maybe_wrap_and_compile_fx_main
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_fx_main(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2864, in _compile_fx_main
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise TritonMissing(inspect.currentframe())
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Traceback (most recent call last):
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 2052, in __call__
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = self._inner_convert(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 729, in __call__
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = _compile(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1827, in _compile
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     guarded_code, tracer_output = compile_inner(code, one_graph, hooks)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_utils_internal.py", line 96, in wrapper_function
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return function(*args, **kwargs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1500, in compile_inner
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_inner(code, one_graph, hooks)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1534, in _compile_inner
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     dynamo_output = compile_frame(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1408, in compile_frame
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     bytecode, tracer_output = transform_code_object(code, transform)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1608, in transform_code_object
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = transformations(instructions, code_options)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1380, in transform
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = trace_frame(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 341, in _fn
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return fn(*args, **kwargs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 863, in trace_frame
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     run_tracer()
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 844, in run_tracer
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer.run()
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1794, in run
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     while self.step():
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]           ^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1459, in step
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.dispatch_table[inst.opcode](self, inst)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5570, in RETURN_VALUE
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self._return(inst)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5552, in _return
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     all_stack_locals_metadata = self.output.compile_subgraph(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 1889, in compile_subgraph
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2460, in compile_and_call_fx_graph
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = self.call_user_compiler(gm, self.example_inputs())
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2613, in call_user_compiler
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return self._call_user_compiler(gm, example_inputs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2664, in _call_user_compiler
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = compiler_fn(gm, example_inputs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 156, in __call__
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_gm = compiler_fn(gm, example_inputs)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\__init__.py", line 2461, in __call__
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2578, in compile_fx
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _maybe_wrap_and_compile_fx_main(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2655, in _maybe_wrap_and_compile_fx_main
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_fx_main(
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2864, in _compile_fx_main
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise TritonMissing(inspect.currentframe())
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# W0913 23:00:29.365000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] WON'T CONVERT forward c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\transformers\models\rt_detr_v2\modeling_rt_detr_v2.py line 1480
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] due to:
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Traceback (most recent call last):
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 2052, in __call__
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = self._inner_convert(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 729, in __call__
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = _compile(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1827, in _compile
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     guarded_code, tracer_output = compile_inner(code, one_graph, hooks)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_utils_internal.py", line 96, in wrapper_function
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return function(*args, **kwargs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1500, in compile_inner
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_inner(code, one_graph, hooks)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1534, in _compile_inner
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     dynamo_output = compile_frame(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1408, in compile_frame
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     bytecode, tracer_output = transform_code_object(code, transform)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1608, in transform_code_object
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = transformations(instructions, code_options)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1380, in transform
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = trace_frame(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 341, in _fn
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return fn(*args, **kwargs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 863, in trace_frame
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     run_tracer()
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 844, in run_tracer
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer.run()
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1794, in run
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     while self.step():
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]           ^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1459, in step
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.dispatch_table[inst.opcode](self, inst)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5570, in RETURN_VALUE
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self._return(inst)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5552, in _return
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     all_stack_locals_metadata = self.output.compile_subgraph(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 1889, in compile_subgraph
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2460, in compile_and_call_fx_graph
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = self.call_user_compiler(gm, self.example_inputs())
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2613, in call_user_compiler
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return self._call_user_compiler(gm, example_inputs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2664, in _call_user_compiler
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = compiler_fn(gm, example_inputs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 156, in __call__
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_gm = compiler_fn(gm, example_inputs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\__init__.py", line 2461, in __call__
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2578, in compile_fx
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _maybe_wrap_and_compile_fx_main(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2655, in _maybe_wrap_and_compile_fx_main
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_fx_main(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2864, in _compile_fx_main
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise TritonMissing(inspect.currentframe())
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Traceback (most recent call last):
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 2052, in __call__
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = self._inner_convert(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 729, in __call__
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = _compile(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1827, in _compile
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     guarded_code, tracer_output = compile_inner(code, one_graph, hooks)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_utils_internal.py", line 96, in wrapper_function
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return function(*args, **kwargs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1500, in compile_inner
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_inner(code, one_graph, hooks)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1534, in _compile_inner
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     dynamo_output = compile_frame(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1408, in compile_frame
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     bytecode, tracer_output = transform_code_object(code, transform)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1608, in transform_code_object
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = transformations(instructions, code_options)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1380, in transform
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = trace_frame(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 341, in _fn
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return fn(*args, **kwargs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 863, in trace_frame
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     run_tracer()
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 844, in run_tracer
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer.run()
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1794, in run
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     while self.step():
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]           ^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1459, in step
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.dispatch_table[inst.opcode](self, inst)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5570, in RETURN_VALUE
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self._return(inst)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5552, in _return
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     all_stack_locals_metadata = self.output.compile_subgraph(
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 1889, in compile_subgraph
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2460, in compile_and_call_fx_graph
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = self.call_user_compiler(gm, self.example_inputs())
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2613, in call_user_compiler
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return self._call_user_compiler(gm, example_inputs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2664, in _call_user_compiler
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = compiler_fn(gm, example_inputs)
# W0913 23:01:00.479000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 156, in __call__
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_gm = compiler_fn(gm, example_inputs)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\__init__.py", line 2461, in __call__
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2578, in compile_fx
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _maybe_wrap_and_compile_fx_main(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2655, in _maybe_wrap_and_compile_fx_main
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_fx_main(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2864, in _compile_fx_main
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise TritonMissing(inspect.currentframe())
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Traceback (most recent call last):
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 2052, in __call__
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = self._inner_convert(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 729, in __call__
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     result = _compile(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]              ^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1827, in _compile
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     guarded_code, tracer_output = compile_inner(code, one_graph, hooks)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_utils_internal.py", line 96, in wrapper_function
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return function(*args, **kwargs)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1500, in compile_inner
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_inner(code, one_graph, hooks)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1534, in _compile_inner
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     dynamo_output = compile_frame(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1408, in compile_frame
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     bytecode, tracer_output = transform_code_object(code, transform)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1608, in transform_code_object
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = transformations(instructions, code_options)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1380, in transform
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer_output = trace_frame(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                     ^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 341, in _fn
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return fn(*args, **kwargs)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 863, in trace_frame
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     run_tracer()
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\convert_frame.py", line 844, in run_tracer
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     tracer.run()
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1794, in run
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     while self.step():
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]           ^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1459, in step
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.dispatch_table[inst.opcode](self, inst)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5570, in RETURN_VALUE
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self._return(inst)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 5552, in _return
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     all_stack_locals_metadata = self.output.compile_subgraph(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 1889, in compile_subgraph
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2460, in compile_and_call_fx_graph
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = self.call_user_compiler(gm, self.example_inputs())
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2613, in call_user_compiler
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return self._call_user_compiler(gm, example_inputs)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\output_graph.py", line 2664, in _call_user_compiler
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_fn = compiler_fn(gm, example_inputs)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 156, in __call__
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     compiled_gm = compiler_fn(gm, example_inputs)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\__init__.py", line 2461, in __call__
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2578, in compile_fx
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _maybe_wrap_and_compile_fx_main(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2655, in _maybe_wrap_and_compile_fx_main
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     return _compile_fx_main(
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]            ^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py", line 2864, in _compile_fx_main
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]     raise TritonMissing(inspect.currentframe())
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147] Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# W0913 23:02:02.678000 11324 Lib\site-packages\torch\_dynamo\convert_frame.py:2147]
# [WARNING] 2026-09-13 23:02:44,910 [RapidOCR] main.py:132: The text detection result is empty
# RapidOCR returned empty result!
# Docling conversion completed.

# %%
# ============================================================
# 2. Parse PDF using Docling
# ============================================================

from docling.document_converter import DocumentConverter

converter = DocumentConverter()

# Convert PDF into Docling structured document
conversion_result = converter.convert(PDF_PATH)

# Main Docling document object
docling_doc = conversion_result.document

print("Docling conversion completed.")
# Out:
# The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# [INFO] 2026-09-13 22:50:31,852 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-13 22:50:31,965 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.onnx
# [INFO] 2026-09-13 22:50:31,966 [RapidOCR] main.py:63: Using C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\PP-OCRv6_det_small.onnx
# [INFO] 2026-09-13 22:50:32,119 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-13 22:50:32,148 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-09-13 22:50:32,149 [RapidOCR] main.py:63: Using C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-09-13 22:50:32,244 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-09-13 22:50:32,332 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\PP-OCRv6_rec_small.onnx
# [INFO] 2026-09-13 22:50:32,333 [RapidOCR] main.py:63: Using C:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\rapidocr\models\PP-OCRv6_rec_small.onnx
# The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ASUS\.cache\huggingface\hub\models--docling-project--docling-layout-heron. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# W0913 22:51:02.259000 11324 Lib\site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ASUS\.cache\huggingface\hub\models--docling-project--docling-models. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\fx_passes\fuse_attention.py:822: UserWarning: TensorFloat32 tensor cores for float32 matrix multiplication available but not enabled. Skipping pattern matching to fused flash-attention. Consider setting `torch.set_float32_matmul_precision('high')` for better performance.
#   warnings.warn(
# c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\compile_fx.py:322: UserWarning: TensorFloat32 tensor cores for float32 matrix multiplication available but not enabled. Consider setting `torch.set_float32_matmul_precision('high')` for better performance.
#   warnings.warn(
# W0913 22:53:05.411000 11324 Lib\site-packages\torch\_inductor\utils.py:1731] [0/0] Not enough SMs to use max_autotune_gemm mode
# Stage layout failed for run 1: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# Traceback (most recent call last):
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py", line 353, in _process_batch
#     processed_pages = list(self.model(good[0].conv_res, pages))  # type: ignore[arg-type]
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\base_layout_model.py", line 59, in __call__
#     predictions = self.predict_layout(conv_res, pages)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\stages\layout\layout_object_detection_model.py", line 112, in predict_layout
#     engine_outputs = self.engine.predict_batch(batch)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\inference_engines\object_detection\transformers_engine.py", line 208, in predict_batch
#     outputs = self._model(**inputs)  # type: ignore[operator]
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 472, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 1038, in compile_wrapper
#     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
#     raise TritonMissing(inspect.currentframe())
# torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
#
# Stage layout failed for run 1: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# Traceback (most recent call last):
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py", line 353, in _process_batch
#     processed_pages = list(self.model(good[0].conv_res, pages))  # type: ignore[arg-type]
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\base_layout_model.py", line 59, in __call__
#     predictions = self.predict_layout(conv_res, pages)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\stages\layout\layout_object_detection_model.py", line 112, in predict_layout
#     engine_outputs = self.engine.predict_batch(batch)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\inference_engines\object_detection\transformers_engine.py", line 208, in predict_batch
#     outputs = self._model(**inputs)  # type: ignore[operator]
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 472, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 1038, in compile_wrapper
#     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
#     raise TritonMissing(inspect.currentframe())
# torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
#
# Stage layout failed for run 1: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# Traceback (most recent call last):
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py", line 353, in _process_batch
#     processed_pages = list(self.model(good[0].conv_res, pages))  # type: ignore[arg-type]
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\base_layout_model.py", line 59, in __call__
#     predictions = self.predict_layout(conv_res, pages)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\stages\layout\layout_object_detection_model.py", line 112, in predict_layout
#     engine_outputs = self.engine.predict_batch(batch)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\inference_engines\object_detection\transformers_engine.py", line 208, in predict_batch
#     outputs = self._model(**inputs)  # type: ignore[operator]
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 472, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 1038, in compile_wrapper
#     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
#     raise TritonMissing(inspect.currentframe())
# torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
#
# Stage layout failed for run 1: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# Traceback (most recent call last):
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py", line 353, in _process_batch
#     processed_pages = list(self.model(good[0].conv_res, pages))  # type: ignore[arg-type]
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\base_layout_model.py", line 59, in __call__
#     predictions = self.predict_layout(conv_res, pages)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\stages\layout\layout_object_detection_model.py", line 112, in predict_layout
#     engine_outputs = self.engine.predict_batch(batch)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\inference_engines\object_detection\transformers_engine.py", line 208, in predict_batch
#     outputs = self._model(**inputs)  # type: ignore[operator]
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 472, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 1038, in compile_wrapper
#     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
#     raise TritonMissing(inspect.currentframe())
# torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
#
# Stage layout failed for run 1: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# Traceback (most recent call last):
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py", line 353, in _process_batch
#     processed_pages = list(self.model(good[0].conv_res, pages))  # type: ignore[arg-type]
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\base_layout_model.py", line 59, in __call__
#     predictions = self.predict_layout(conv_res, pages)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\stages\layout\layout_object_detection_model.py", line 112, in predict_layout
#     engine_outputs = self.engine.predict_batch(batch)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\inference_engines\object_detection\transformers_engine.py", line 208, in predict_batch
#     outputs = self._model(**inputs)  # type: ignore[operator]
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 472, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 1038, in compile_wrapper
#     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
#     raise TritonMissing(inspect.currentframe())
# torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
#
# Stage layout failed for run 1: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# Traceback (most recent call last):
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py", line 353, in _process_batch
#     processed_pages = list(self.model(good[0].conv_res, pages))  # type: ignore[arg-type]
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\base_layout_model.py", line 59, in __call__
#     predictions = self.predict_layout(conv_res, pages)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\stages\layout\layout_object_detection_model.py", line 112, in predict_layout
#     engine_outputs = self.engine.predict_batch(batch)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\inference_engines\object_detection\transformers_engine.py", line 208, in predict_batch
#     outputs = self._model(**inputs)  # type: ignore[operator]
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 472, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 1038, in compile_wrapper
#     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
#     raise TritonMissing(inspect.currentframe())
# torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
#
# Stage layout failed for run 1: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# Traceback (most recent call last):
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\pipeline\standard_pdf_pipeline.py", line 353, in _process_batch
#     processed_pages = list(self.model(good[0].conv_res, pages))  # type: ignore[arg-type]
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\base_layout_model.py", line 59, in __call__
#     predictions = self.predict_layout(conv_res, pages)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\stages\layout\layout_object_detection_model.py", line 112, in predict_layout
#     engine_outputs = self.engine.predict_batch(batch)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\models\inference_engines\object_detection\transformers_engine.py", line 208, in predict_batch
#     outputs = self._model(**inputs)  # type: ignore[operator]
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 472, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\nn\modules\module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_dynamo\eval_frame.py", line 1038, in compile_wrapper
#     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\torch\_inductor\scheduler.py", line 5908, in create_backend
#     raise TritonMissing(inspect.currentframe())
# torch._inductor.exc.TritonMissing: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ---------------------------------------------------------------------------
# ConversionError                           Traceback (most recent call last)
# Cell In[26], line 10
#       6
#       7 converter = DocumentConverter()
#       8
#       9 # Convert PDF into Docling structured document
# ---> 10 conversion_result = converter.convert(PDF_PATH)
#      11
#      12 # Main Docling document object
#      13 docling_doc = conversion_result.document
#
# File c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\pydantic\_internal\_validate_call.py:40, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      38 @functools.wraps(wrapped)
#      39 def wrapper_function(*args, **kwargs):
# ---> 40     return wrapper(*args, **kwargs)
#
# File c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\pydantic\_internal\_validate_call.py:137, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     134 if not self.__pydantic_complete__:
#     135     self._create_validators()
# --> 137 res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     138 if self.__return_pydantic_validator__:
#     139     return self.__return_pydantic_validator__(res)
#
# File c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\document_converter.py:503, in DocumentConverter.convert(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     450 """Convert one document fetched from a file path, URL, or DocumentStream.
#     451
#     452 Note: If the document content is given as a string (Markdown or HTML
#    (...)    493     >>> result = converter.convert(stream)
#     494 """
#     495 all_res = self.convert_all(
#     496     source=[source],
#     497     raises_on_error=raises_on_error,
#    (...)    501     page_range=page_range,
#     502 )
# --> 503 return next(all_res)
#
# File c:\Users\ASUS\Desktop\Gen AI Full stak\env\Lib\site-packages\docling\document_converter.py:579, in DocumentConverter.convert_all(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     574         error_details = f" Errors: {'; '.join(error_messages)}"
#     575     # Chain the underlying exception (when one was captured during
#     576     # input construction) so callers can classify failures via
#     577     # ``__cause__`` — e.g. an encrypted PDF surfaces the original
#     578     # ``PdfiumError``. See issue #1920.
# --> 579     raise ConversionError(
#     580         f"Conversion failed for: {conv_res.input.file} with status: "
#     581         f"{conv_res.status.value}.{error_details}"
#     582     ) from get_input_rejection_cause(conv_res.input)
#     583 else:
#     584     yield conv_res
#
# ConversionError: Conversion failed for: complex_rag_parsing_sample_with_sunny_image.pdf with status: failure. Errors: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
# ; Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at: https://github.com/triton-lang/triton
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"

# %%
# ============================================================
# 3. Export Parsed Output to Markdown
# ============================================================

markdown_text = docling_doc.export_to_markdown()

markdown_path = OUTPUT_DIR / "parsed_docling_output.md"

with open(markdown_path, "w", encoding="utf-8") as f:
    f.write(markdown_text)

print("Markdown saved at:", markdown_path)
# Out:
# Markdown saved at: C:\Users\ASUS\Desktop\Gen AI Full stak\class_18_data_parsing\output\docling_parsed_output\parsed_docling_output.md

# %%
# ============================================================
# 4. Export Parsed Output to JSON / Dict
# ============================================================

# Docling versions may expose export_to_dict() or model_dump()
# This fallback handles both styles.

try:
    doc_dict = docling_doc.export_to_dict()
except Exception:
    try:
        doc_dict = docling_doc.model_dump()
    except Exception:
        doc_dict = {"raw_string": str(docling_doc)}

json_path = OUTPUT_DIR / "parsed_docling_output.json"

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(doc_dict, f, indent=2, ensure_ascii=False)

print("JSON saved at:", json_path)
# Out:
# JSON saved at: D:\complete_content_new\Full-Stack-GenAI-Bootcamp-1.0\Class-30-Data-Parsing-for-RAG\output\docling_parsed_output\parsed_docling_output.json

# %%
# ============================================================
# 5. Create LangChain Document from Full Markdown
# ============================================================

full_doc = Document(
    page_content=markdown_text,
    metadata={
        "source": PDF_PATH,
        "parser": "docling",
        "content_type": "full_document_markdown"
    }
)

print("LangChain full document created.")
print("Characters:", len(full_doc.page_content))
# Out:
# LangChain full document created.
# Characters: 35530

# %%
# # ============================================================
# # 6. Split Markdown into RAG-ready Chunks
# # ============================================================

# text_splitter = RecursiveCharacterTextSplitter(
#     chunk_size=1200,
#     chunk_overlap=200,
#     separators=[
#         "\n# ",
#         "\n## ",
#         "\n### ",
#         "\n\n",
#         "\n",
#         " ",
#         ""
#     ]
# )

# chunks = text_splitter.split_documents([full_doc])

# print("Total chunks created:", len(chunks))

# for i, chunk in enumerate(chunks[:3]):
#     print(f"\n--- Chunk {i + 1} ---")
#     print("Metadata:", chunk.metadata)
#     print(chunk.page_content[:800])


# # ============================================================
# # 7. Save RAG-ready Chunks as JSONL
# # ============================================================

# chunks_jsonl_path = OUTPUT_DIR / "rag_ready_chunks.jsonl"

# with open(chunks_jsonl_path, "w", encoding="utf-8") as f:
#     for i, chunk in enumerate(chunks):
#         record = {
#             "chunk_id": i + 1,
#             "page_content": chunk.page_content,
#             "metadata": chunk.metadata
#         }
#         f.write(json.dumps(record, ensure_ascii=False) + "\n")

# print("Chunks JSONL saved at:", chunks_jsonl_path)


# # ============================================================
# # 8. Save RAG-ready Chunks as Markdown Preview
# # ============================================================

# chunks_md_path = OUTPUT_DIR / "rag_ready_chunks_preview.md"

# with open(chunks_md_path, "w", encoding="utf-8") as f:
#     for i, chunk in enumerate(chunks):
#         f.write(f"\n\n# Chunk {i + 1}\n")
#         f.write("```json\n")
#         f.write(json.dumps(chunk.metadata, indent=2, ensure_ascii=False))
#         f.write("\n```\n\n")
#         f.write(chunk.page_content)
#         f.write("\n\n---\n")

# print("Chunks markdown preview saved at:", chunks_md_path)


# # ============================================================
# # 9. Basic Search Test on Parsed Markdown
# # ============================================================

# keywords = [
#     "Appendix A",
#     "Complex Clause Responsibility Matrix",
#     "Appendix G",
#     "Scanned Tax Invoice",
#     "Appendix H",
#     "Scanned Utility Bill",
#     "Appendix I",
#     "Profile Image",
#     "Retention Heatmap",
#     "Vector Database"
# ]

# print("\nKeyword check:")
# for keyword in keywords:
#     found = keyword.lower() in markdown_text.lower()
#     print(f"{keyword}: {found}")


# # ============================================================
# # 10. Final Output Summary
# # ============================================================

# print("\nDONE.")
# print("Output folder:", OUTPUT_DIR)
# print("Files created:")
# print("-", markdown_path.name)
# print("-", json_path.name)
# print("-", chunks_jsonl_path.name)
# print("-", chunks_md_path.name)

# print("\nUse 'chunks' for embeddings/vector database.")

# %%
# !pip install -q langchain-docling langchain-text-splitters

# from langchain_docling import DoclingLoader
# from langchain_text_splitters import RecursiveCharacterTextSplitter

# PDF_PATH = "/mnt/data/complex_rag_parsing_sample_with_sunny_image.pdf"

# loader = DoclingLoader(file_path=PDF_PATH)

# docs = loader.load()

# print("Total docs:", len(docs))
# print(docs[0].page_content[:1000])
# print(docs[0].metadata)

# splitter = RecursiveCharacterTextSplitter(
#     chunk_size=1200,
#     chunk_overlap=200
# )

# chunks = splitter.split_documents(docs)

# print("Total chunks:", len(chunks))
